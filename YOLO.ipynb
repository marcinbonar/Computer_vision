# %% [markdown]
# <a href="https://colab.research.google.com/github/marcinbonar/Computer_vision/blob/main/YOLO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Template

# %%
print('Hello Colad')
# Out:
# Hello Colad
